# %%
import cv2
import json
import numpy as np
from pathlib import Path
from datetime import datetime
from typing import List, Dict, Any

# %%
def convert_segment_masks_to_yolo_seg(masks_dir: str, output_dir: str, bbox_output_dir: str = None, classes: int = 80):
    """
    Convert a dataset of segmentation mask images to the YOLO segmentation format.

    This function takes the directory containing the binary format mask images and converts them into YOLO segmentation
    format. The converted masks are saved in the specified output directory.

    Args:
        masks_dir (str): The path to the directory where all mask images (png, jpg) are stored.
        output_dir (str): The path to the directory where the converted YOLO segmentation masks will be stored.
        classes (int): Total classes in the dataset i.e. for COCO classes=80

    """
    Path(output_dir).mkdir(parents=True, exist_ok=True)
    Path(bbox_output_dir).mkdir(parents=True, exist_ok=True)

    #Multiclass
    #pixel_to_class_mapping = {i + 1: i for i in range(classes)}
    
    # For binary masks: pixel 0 = background, pixel 255 = class 0  
    pixel_to_class_mapping = {255: 0}  # Map pixel value 255 to class 0
    
    for mask_path in Path(masks_dir).iterdir():
        if mask_path.suffix in {".png", ".jpg", ".tiff"}:
            mask = cv2.imread(str(mask_path), cv2.IMREAD_GRAYSCALE)  # Read the mask image in grayscale
            img_height, img_width = mask.shape  # Get image dimensions
            print(f"Processing {mask_path} imgsz = {img_height} x {img_width}")

            unique_values = np.unique(mask)  # Get unique pixel values representing different classes
            yolo_format_data = []
            bbox_format_data = []

            for value in unique_values:
                if value == 0:
                    continue  # Skip background
                class_index = pixel_to_class_mapping.get(value, -1)
                if class_index == -1:
                    print(f"Unknown class for pixel value {value} in file {mask_path}, skipping.")
                    continue

                # Create a binary mask for the current class and find contours
                binary_mask = (mask == value).astype(np.uint8)
                contours, _ = cv2.findContours(
                    binary_mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE
                )  # Find contours

                for contour in contours:
                    if len(contour) >= 3:  # YOLO requires at least 3 points for a valid segmentation
                        contour = contour.squeeze()  # Remove single-dimensional entries
                        
                        yolo_format = [class_index]
                        for point in contour:
                            # Normalize the coordinates
                            yolo_format.append(round(point[0] / img_width, 6))  # Rounding to 6 decimal places
                            yolo_format.append(round(point[1] / img_height, 6))
                        yolo_format_data.append(yolo_format)

                    x, y, w, h = cv2.boundingRect(contour)
                    center_x = (x + w / 2) / img_width
                    center_y = (y + h / 2) / img_height
                    norm_width = w / img_width
                    norm_height = h / img_height

                    bbox_format = [
                        class_index,
                        round(center_x, 6),
                        round(center_y, 6),
                        round(norm_width, 6),
                        round(norm_height, 6)
                    ]
                    bbox_format_data.append(bbox_format)
            
            # Save YOLO format data to file
            seg_output_path = Path(output_dir) / f"{mask_path.stem}.txt"
            with open(seg_output_path, "w", encoding="utf-8") as file:
                for item in yolo_format_data:
                    line = " ".join(map(str, item))
                    file.write(line + "\n")

            if bbox_output_dir is not None:
                # Save YOLO bounding box format data to file
                bbox_output_path = Path(bbox_output_dir) / f"{mask_path.stem}.txt"
                with open(bbox_output_path, "w", encoding="utf-8") as file:
                    for item in bbox_format_data:
                        line = " ".join(map(str, item))
                        file.write(line + "\n")
            
            print(f"Processed and stored:")
            print(f"  Segmentation: {seg_output_path}")
            print(f"  Bounding boxes: {bbox_output_path}")
            print(f"  Image size: {img_height} x {img_width}")

# %%
def convert_segment_masks_to_coco(masks_dir: str, output_file: str, category_name: str = "object", 
                                 category_id: int = 1, dataset_name: str = "Custom Dataset"):
    """
    Convert binary segmentation mask images to COCO format JSON.
    
    Args:
        masks_dir (str): Path to directory containing binary mask images (0=background, 255=object)
        output_file (str): Path where the COCO JSON file will be saved
        category_name (str): Name of the object category (default: "object")
        category_id (int): ID of the object category (default: 1)
        dataset_name (str): Name of the dataset (default: "Custom Dataset")
        
    Returns:
        dict: COCO format dictionary
        
    Example:
        >>> convert_segment_masks_to_coco(
        ...     masks_dir="masks/",
        ...     output_file="annotations.json",
        ...     category_name="person",
        ...     category_id=1
        ... )
    """
    
    # Initialize COCO structure
    coco_data = {
        "info": {
            "description": dataset_name,
            "url": "",
            "version": "1.0",
            "year": datetime.now().year,
            "contributor": "Auto-generated",
            "date_created": datetime.now().isoformat()
        },
        "licenses": [
            {
                "id": 1,
                "name": "Unknown",
                "url": ""
            }
        ],
        "images": [],
        "annotations": [],
        "categories": [
            {
                "id": category_id,
                "name": category_name,
                "supercategory": "object"
            }
        ]
    }
    
    annotation_id = 1
    image_id = 1
    
    # Process each mask file
    for mask_path in sorted(Path(masks_dir).iterdir()):
        if mask_path.suffix.lower() in {".png", ".jpg", ".jpeg"}:
            print(f"Processing {mask_path.name}...")
            
            # Read mask
            mask = cv2.imread(str(mask_path), cv2.IMREAD_GRAYSCALE)
            if mask is None:
                print(f"Warning: Could not read {mask_path}")
                continue
                
            img_height, img_width = mask.shape
            
            # Add image info
            image_info = {
                "id": image_id,
                "width": img_width,
                "height": img_height,
                "file_name": mask_path.name,
                "license": 1,
                "flickr_url": "",
                "coco_url": "",
                "date_captured": datetime.now().isoformat()
            }
            coco_data["images"].append(image_info)
            
            # Find contours for objects (pixel value 255)
            binary_mask = (mask == 255).astype(np.uint8)
            contours, _ = cv2.findContours(binary_mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
            
            for contour in contours:
                if len(contour) >= 3:  # Valid contour
                    # Calculate area
                    area = cv2.contourArea(contour)
                    if area < 1:  # Skip very small areas
                        continue
                    
                    # Get bounding box
                    x, y, w, h = cv2.boundingRect(contour)
                    bbox = [float(x), float(y), float(w), float(h)]
                    
                    # Convert contour to segmentation format
                    contour = contour.squeeze()
                    if contour.ndim == 1:  # Single point case
                        contour = contour.reshape(1, -1)
                    
                    segmentation = []
                    for point in contour:
                        segmentation.extend([float(point[0]), float(point[1])])
                    
                    # Create annotation
                    annotation = {
                        "id": annotation_id,
                        "image_id": image_id,
                        "category_id": category_id,
                        "segmentation": [segmentation],
                        "area": float(area),
                        "bbox": bbox,
                        "iscrowd": 0
                    }
                    
                    coco_data["annotations"].append(annotation)
                    annotation_id += 1
            
            image_id += 1
    
    # Save COCO JSON file
    output_path = Path(output_file)
    output_path.parent.mkdir(parents=True, exist_ok=True)
    
    with open(output_path, 'w', encoding='utf-8') as f:
        json.dump(coco_data, f, indent=2, ensure_ascii=False)
    
    print(f"\nCOCO annotations saved to: {output_path}")
    print(f"Total images: {len(coco_data['images'])}")
    print(f"Total annotations: {len(coco_data['annotations'])}")
    
    return coco_data


def convert_segment_masks_to_coco_multi_class(masks_dir: str, output_file: str, 
                                            class_mapping: Dict[int, str],
                                            dataset_name: str = "Custom Dataset"):
    """
    Convert multi-class segmentation masks to COCO format JSON.
    Supports masks where different pixel values represent different classes.
    
    Args:
        masks_dir (str): Path to directory containing mask images
        output_file (str): Path where the COCO JSON file will be saved
        class_mapping (Dict[int, str]): Mapping from pixel values to class names
                                       Example: {255: "person", 128: "car", 64: "bicycle"}
        dataset_name (str): Name of the dataset
        
    Example:
        >>> class_mapping = {255: "person", 128: "car"}
        >>> convert_segment_masks_to_coco_multi_class(
        ...     masks_dir="masks/",
        ...     output_file="annotations.json",
        ...     class_mapping=class_mapping
        ... )
    """
    
    # Create categories from class mapping
    categories = []
    for pixel_value, class_name in class_mapping.items():
        categories.append({
            "id": pixel_value,
            "name": class_name,
            "supercategory": "object"
        })
    
    # Initialize COCO structure
    coco_data = {
        "info": {
            "description": dataset_name,
            "url": "",
            "version": "1.0",
            "year": datetime.now().year,
            "contributor": "Auto-generated",
            "date_created": datetime.now().isoformat()
        },
        "licenses": [
            {
                "id": 1,
                "name": "Unknown",
                "url": ""
            }
        ],
        "images": [],
        "annotations": [],
        "categories": categories
    }
    
    annotation_id = 1
    image_id = 1
    
    # Process each mask file
    for mask_path in sorted(Path(masks_dir).iterdir()):
        if mask_path.suffix.lower() in {".png", ".jpg", ".jpeg"}:
            print(f"Processing {mask_path.name}...")
            
            # Read mask
            mask = cv2.imread(str(mask_path), cv2.IMREAD_GRAYSCALE)
            if mask is None:
                print(f"Warning: Could not read {mask_path}")
                continue
                
            img_height, img_width = mask.shape
            
            # Add image info
            image_info = {
                "id": image_id,
                "width": img_width,
                "height": img_height,
                "file_name": mask_path.name,
                "license": 1,
                "flickr_url": "",
                "coco_url": "",
                "date_captured": datetime.now().isoformat()
            }
            coco_data["images"].append(image_info)
            
            # Process each class
            for pixel_value, class_name in class_mapping.items():
                # Create binary mask for this class
                binary_mask = (mask == pixel_value).astype(np.uint8)
                contours, _ = cv2.findContours(binary_mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
                
                for contour in contours:
                    if len(contour) >= 3:  # Valid contour
                        # Calculate area
                        area = cv2.contourArea(contour)
                        if area < 1:  # Skip very small areas
                            continue
                        
                        # Get bounding box
                        x, y, w, h = cv2.boundingRect(contour)
                        bbox = [float(x), float(y), float(w), float(h)]
                        
                        # Convert contour to segmentation format
                        contour = contour.squeeze()
                        if contour.ndim == 1:  # Single point case
                            contour = contour.reshape(1, -1)
                        
                        segmentation = []
                        for point in contour:
                            segmentation.extend([float(point[0]), float(point[1])])
                        
                        # Create annotation
                        annotation = {
                            "id": annotation_id,
                            "image_id": image_id,
                            "category_id": pixel_value,
                            "segmentation": [segmentation],
                            "area": float(area),
                            "bbox": bbox,
                            "iscrowd": 0
                        }
                        
                        coco_data["annotations"].append(annotation)
                        annotation_id += 1
            
            image_id += 1
    
    # Save COCO JSON file
    output_path = Path(output_file)
    output_path.parent.mkdir(parents=True, exist_ok=True)
    
    with open(output_path, 'w', encoding='utf-8') as f:
        json.dump(coco_data, f, indent=2, ensure_ascii=False)
    
    print(f"\nCOCO annotations saved to: {output_path}")
    print(f"Total images: {len(coco_data['images'])}")
    print(f"Total annotations: {len(coco_data['annotations'])}")
    print(f"Categories: {[cat['name'] for cat in categories]}")
    
    return coco_data


def validate_coco_json(json_file: str) -> bool:
    """
    Validate COCO JSON format and print statistics.
    
    Args:
        json_file (str): Path to COCO JSON file
        
    Returns:
        bool: True if valid, False otherwise
    """
    try:
        with open(json_file, 'r', encoding='utf-8') as f:
            data = json.load(f)
        
        # Check required fields
        required_fields = ['info', 'images', 'annotations', 'categories']
        for field in required_fields:
            if field not in data:
                print(f"Error: Missing required field '{field}'")
                return False
        
        print("COCO JSON Validation Results:")
        print(f"✓ Total images: {len(data['images'])}")
        print(f"✓ Total annotations: {len(data['annotations'])}")
        print(f"✓ Total categories: {len(data['categories'])}")
        
        # Print categories
        print("\nCategories:")
        for cat in data['categories']:
            cat_annotations = [ann for ann in data['annotations'] if ann['category_id'] == cat['id']]
            print(f"  - {cat['name']} (ID: {cat['id']}): {len(cat_annotations)} annotations")
        
        return True
        
    except Exception as e:
        print(f"Error validating COCO JSON: {e}")
        return False


# Example usage

# Example 1: Binary masks (0=background, 255=object)
# convert_segment_masks_to_coco(
#     masks_dir="path/to/binary_masks",
#     output_file="annotations_binary.json",
#     category_name="person",
#     category_id=1
# )

# Example 2: Multi-class masks
# class_mapping = {
#     255: "person",
#     128: "car", 
#     64: "bicycle"
# }
# convert_segment_masks_to_coco_multi_class(
#     masks_dir="path/to/multiclass_masks",
#     output_file="annotations_multiclass.json",
#     class_mapping=class_mapping
# )

# Example 3: Validate generated JSON
# validate_coco_json("annotations.json")

# %%
convert_segment_masks_to_yolo_seg(
    masks_dir="./masks", 
    output_dir = "./data/seg", 
    bbox_output_dir = "./data/bbox",
    classes=1)
# Out:
# Processing ../data/raw/dataset/masks/dataset4_01006.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_01006.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_01006.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_01725.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_01725.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_01725.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_02101.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_02101.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_02101.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_01007.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_01007.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_01007.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_00908.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_00908.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_00908.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_02042.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_02042.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_02042.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_01886.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_01886.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_01886.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_01077.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_01077.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_01077.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_03096.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_03096.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_03096.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_01626.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_01626.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_01626.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_03202.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_03202.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_03202.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_03478.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_03478.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_03478.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_03619.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_03619.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_03619.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_03386.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_03386.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_03386.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_03327.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_03327.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_03327.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_00345.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_00345.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_00345.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_00936.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_00936.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_00936.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_03740.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_03740.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_03740.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_01889.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_01889.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_01889.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_02327.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_02327.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_02327.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_03057.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_03057.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_03057.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_00004.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_00004.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_00004.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_02593.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_02593.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_02593.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_00426.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_00426.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_00426.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_03236.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_03236.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_03236.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_03645.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_03645.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_03645.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_02780.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_02780.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_02780.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_04061.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_04061.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_04061.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_03268.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_03268.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_03268.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_03388.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_03388.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_03388.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_03797.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_03797.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_03797.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_01640.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_01640.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_01640.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_03024.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_03024.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_03024.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_02309.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_02309.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_02309.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_02540.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_02540.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_02540.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_01998.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_01998.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_01998.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_03193.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_03193.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_03193.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_01177.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_01177.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_01177.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_01475.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_01475.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_01475.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_01220.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_01220.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_01220.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_00993.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_00993.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_00993.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_01703.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_01703.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_01703.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_03812.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_03812.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_03812.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_01609.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_01609.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_01609.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_02404.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_02404.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_02404.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_01124.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_01124.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_01124.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_01909.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_01909.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_01909.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_01380.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_01380.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_01380.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_00289.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_00289.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_00289.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_02074.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_02074.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_02074.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_00265.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_00265.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_00265.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_03047.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_03047.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_03047.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_00819.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_00819.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_00819.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_01406.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_01406.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_01406.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_00729.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_00729.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_00729.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_02859.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_02859.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_02859.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_00814.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_00814.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_00814.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_02117.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_02117.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_02117.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_00037.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_00037.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_00037.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_02391.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_02391.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_02391.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_02179.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_02179.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_02179.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_00843.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_00843.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_00843.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_03823.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_03823.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_03823.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_02636.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_02636.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_02636.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_04096.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_04096.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_04096.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_02826.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_02826.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_02826.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_01073.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_01073.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_01073.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_02918.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_02918.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_02918.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_02989.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_02989.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_02989.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_03321.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_03321.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_03321.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_03814.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_03814.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_03814.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_01473.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_01473.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_01473.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_02120.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_02120.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_02120.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_03856.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_03856.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_03856.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_01927.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_01927.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_01927.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_00599.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_00599.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_00599.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_00663.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_00663.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_00663.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_03390.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_03390.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_03390.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_00858.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_00858.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_00858.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_00419.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_00419.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_00419.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_02834.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_02834.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_02834.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_03022.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_03022.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_03022.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_03564.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_03564.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_03564.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_00496.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_00496.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_00496.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_03624.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_03624.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_03624.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_01481.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_01481.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_01481.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_02683.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_02683.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_02683.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_03723.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_03723.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_03723.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_01485.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_01485.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_01485.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_03103.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_03103.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_03103.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_04101.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_04101.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_04101.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_02496.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_02496.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_02496.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_01118.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_01118.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_01118.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_01058.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_01058.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_01058.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_02135.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_02135.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_02135.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_03063.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_03063.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_03063.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_01777.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_01777.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_01777.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_04042.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_04042.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_04042.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_00248.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_00248.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_00248.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_01067.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_01067.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_01067.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_02672.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_02672.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_02672.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_03725.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_03725.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_03725.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_03692.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_03692.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_03692.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_03520.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_03520.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_03520.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_01580.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_01580.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_01580.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_00300.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_00300.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_00300.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_02217.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_02217.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_02217.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_00994.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_00994.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_00994.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_01600.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_01600.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_01600.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_01863.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_01863.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_01863.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_01106.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_01106.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_01106.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_02772.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_02772.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_02772.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_00247.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_00247.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_00247.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_01577.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_01577.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_01577.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_03881.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_03881.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_03881.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_04120.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_04120.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_04120.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_02719.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_02719.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_02719.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_03315.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_03315.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_03315.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_00578.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_00578.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_00578.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_01840.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_01840.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_01840.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_00645.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_00645.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_00645.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_01595.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_01595.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_01595.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_03896.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_03896.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_03896.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_01945.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_01945.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_01945.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_03418.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_03418.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_03418.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_02388.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_02388.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_02388.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_02422.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_02422.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_02422.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_03445.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_03445.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_03445.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_03642.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_03642.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_03642.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_00267.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_00267.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_00267.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_01803.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_01803.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_01803.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_00342.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_00342.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_00342.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_00563.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_00563.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_00563.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_01958.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_01958.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_01958.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_00304.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_00304.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_00304.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_01081.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_01081.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_01081.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_01718.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_01718.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_01718.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_03077.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_03077.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_03077.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_00415.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_00415.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_00415.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_03724.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_03724.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_03724.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_00309.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_00309.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_00309.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_01137.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_01137.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_01137.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_01608.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_01608.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_01608.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_01178.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_01178.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_01178.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_00614.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_00614.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_00614.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_00573.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_00573.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_00573.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_01656.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_01656.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_01656.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_03516.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_03516.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_03516.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_03487.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_03487.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_03487.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_01949.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_01949.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_01949.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_02550.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_02550.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_02550.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_00970.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_00970.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_00970.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_01085.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_01085.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_01085.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_00991.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_00991.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_00991.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_03098.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_03098.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_03098.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_02183.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_02183.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_02183.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_02623.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_02623.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_02623.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_02794.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_02794.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_02794.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_01121.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_01121.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_01121.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_03799.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_03799.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_03799.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_01328.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_01328.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_01328.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_02730.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_02730.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_02730.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_03070.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_03070.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_03070.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_03840.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_03840.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_03840.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_03809.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_03809.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_03809.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_03019.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_03019.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_03019.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_04006.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_04006.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_04006.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_02548.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_02548.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_02548.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_01643.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_01643.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_01643.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_01899.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_01899.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_01899.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_04139.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_04139.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_04139.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_01824.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_01824.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_01824.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_03550.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_03550.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_03550.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_02164.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_02164.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_02164.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_03634.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_03634.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_03634.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_01877.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_01877.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_01877.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_01316.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_01316.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_01316.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_00529.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_00529.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_00529.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_02952.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_02952.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_02952.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_03946.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_03946.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_03946.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_01891.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_01891.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_01891.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_00591.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_00591.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_00591.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_01874.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_01874.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_01874.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_00380.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_00380.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_00380.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_04018.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_04018.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_04018.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_01168.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_01168.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_01168.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_02107.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_02107.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_02107.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_01671.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_01671.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_01671.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_03167.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_03167.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_03167.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_02915.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_02915.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_02915.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_01020.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_01020.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_01020.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_02461.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_02461.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_02461.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_00383.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_00383.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_00383.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_00983.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_00983.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_00983.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_03848.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_03848.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_03848.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_00585.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_00585.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_00585.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_03879.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_03879.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_03879.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_00789.tiff imgsz = 640 x 640
# Processed and stored:
# ...
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_03745.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_03745.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_02176.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_02176.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_02176.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_03495.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_03495.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_03495.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_00435.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_00435.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_00435.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_00508.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_00508.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_00508.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_03541.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_03541.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_03541.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_01240.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_01240.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_01240.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_02501.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_02501.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_02501.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_01625.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_01625.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_01625.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_03322.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_03322.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_03322.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_03013.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_03013.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_03013.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_02162.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_02162.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_02162.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_03085.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_03085.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_03085.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_02353.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_02353.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_02353.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_03025.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_03025.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_03025.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_01126.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_01126.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_01126.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_02817.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_02817.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_02817.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_01399.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_01399.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_01399.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_01477.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_01477.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_01477.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_03866.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_03866.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_03866.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_00082.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_00082.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_00082.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_02023.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_02023.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_02023.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_02311.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_02311.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_02311.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_02301.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_02301.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_02301.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_01320.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_01320.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_01320.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_00335.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_00335.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_00335.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_03571.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_03571.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_03571.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_02980.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_02980.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_02980.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_03638.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_03638.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_03638.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_04040.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_04040.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_04040.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_02961.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_02961.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_02961.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_02326.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_02326.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_02326.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_01700.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_01700.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_01700.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_03930.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_03930.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_03930.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_03561.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_03561.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_03561.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_03576.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_03576.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_03576.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_03570.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_03570.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_03570.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_01427.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_01427.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_01427.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_00001.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_00001.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_00001.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_02294.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_02294.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_02294.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_01214.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_01214.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_01214.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_03971.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_03971.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_03971.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_03489.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_03489.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_03489.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_00595.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_00595.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_00595.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_03555.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_03555.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_03555.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_03806.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_03806.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_03806.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_00115.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_00115.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_00115.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_02643.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_02643.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_02643.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_03558.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_03558.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_03558.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_02871.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_02871.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_02871.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_01641.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_01641.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_01641.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_00688.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_00688.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_00688.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_03589.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_03589.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_03589.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_02764.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_02764.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_02764.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_00941.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_00941.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_00941.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_02842.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_02842.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_02842.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_02900.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_02900.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_02900.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_01205.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_01205.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_01205.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_00347.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_00347.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_00347.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_04103.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_04103.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_04103.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_02075.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_02075.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_02075.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_03215.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_03215.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_03215.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_03159.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_03159.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_03159.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_00492.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_00492.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_00492.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_03698.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_03698.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_03698.txt
#   Image size: 640 x 640
# Processing ../data/raw/dataset/masks/dataset4_01809.tiff imgsz = 640 x 640
# Processed and stored:
#   Segmentation: ../data/raw/dataset/test/dataset4_01809.txt
#   Bounding boxes: ../data/raw/dataset/bbox/dataset4_01809.txt
#   Image size: 640 x 640
